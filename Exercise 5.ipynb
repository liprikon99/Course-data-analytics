# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Eternity/taxi_peru.csv', sep=';')

# %%
df.head()
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#         icon start_type             start_at     start_lat     start_lon  \
# ...

# %% [markdown]
# ### 1.1 В переменной df находится датафрэйм. Ваша задача положить в переменную  df_shape строку с информацией сколько линий и столбцов он имеет в следующем виде:
# 'df has y rows and x columns'
# где y – число строк, а x – число колонок.

# %%
print('df has {} rows nad {} columns'.format(df.shape[0], df.shape[1]))
# Out:
# df has 23111 rows nad 19 columns

# %%
df.shape
# Out:
# (23111, 19)

# %% [markdown]
# ### 1.2 Положите в переменную na_number серию, в которой для каждой колонки указано сколько ячеек содержат пропущенные значения. Например, для такого датафрэйма: task2_1.png (в папке)
# Ответ будет: task2_2.png (в папке)
# ![zzz](./task2_2.png)

# %%
df.isna().sum()
# Out:
# journey_id              0
# user_id                 0
# driver_id            3385
# taxi_id              3385
# icon                    0
# start_type              0
# start_at                0
# start_lat               0
# start_lon               0
# end_at                276
# end_lat                 0
# end_lon                 0
# end_state              12
# driver_start_lat     3490
# driver_start_lon     3490
# arrived_at           5395
# source                123
# driver_score        15461
# rider_score          7721
# dtype: int64

# %% [markdown]
# ### 1.3 Сохраните в переменную df_types типы данных каждой колонки датафрэйма df.

# %%
df.dtypes
# Out:
# journey_id           object
# user_id              object
# driver_id            object
# taxi_id              object
# icon                 object
# start_type           object
# start_at             object
# start_lat            object
# start_lon            object
# end_at               object
# end_lat              object
# end_lon              object
# end_state            object
# driver_start_lat     object
# driver_start_lon     object
# arrived_at           object
# source               object
# driver_score        float64
# rider_score         float64
# dtype: object

# %% [markdown]
# ### 1.4 Внезапно оказалось, что в переменной age значения хранятся в виде строк! Поменяйте тип значений на целочисленный в этой колонке датафрэйма df.

# %%
df['driver_score']
# Out:
# 0        5.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        4.0
#         ...
# 23106    5.0
# 23107    NaN
# 23108    0.0
# 23109    NaN
# 23110    NaN
# Name: driver_score, Length: 23111, dtype: float64

# %%
df['driver_score'].apply(lambda x: str(x)).dtype
# Out:
# dtype('O')

# %% [markdown]
# ### 1.5 Как выяснилось, для дальнейшего анализа нам не понадобятся колонки icon и start_type – удалите их из датафрэйма.

# %%
df.head()
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#         icon start_type             start_at     start_lat     start_lon  \
# ...

# %%
df = df.drop(columns=['icon', 'start_type'])

# %%
df.head()
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#               start_at     start_lat     start_lon               end_at  \
# ...

# %% [markdown]
# ### 1.6 А теперь проверим, есть ли в нашей таблице df дубликаты по полю user_id – дропните все строки, в которых значения в колонке client_id повторяются.

# %%
df.shape
# Out:
# (23111, 17)

# %%
df.drop_duplicates(subset=['user_id']).shape
# Out:
# (1390, 17)

# %% [markdown]
# ### 1.7 Небольшой перерыв на чистый питон. В списке numbers содержатся числа. Добавьте через цикл в список positive_numbers положительные числа из numbers. При этом, если вам попался 0, то нужно прекратить этот цикл.
# Например,
# numbers = [1, -2, 3, 0, -3, 2]
# Тогда positive_numbers должен быть:
# positive_numbers = [1, 3]

# %%
numbers = [1, -2, 3, 0, -3, 2]
positive_numbers = []
def positive_from_list(numbers):
    for number in numbers:
        trigger = True
        if number == 0:
            trigger = False
            break
            
        if trigger:
            if number > 0:
                positive_numbers.append(number)
positive_from_list(numbers)                
print(positive_numbers)
# Out:
# [1, 3]

# %% [markdown]
# ### 1.8 Продолжим анализ данных по поездкам. В предыдущем уроке вы изучили распределения оценок водителей и клиентов. Теперь посмотрим на колонки со временем!
# Сохраните данные, находящиеся в папке (taxi_peru.csv), в переменную taxi, разделитель – ;. Затем приведите столбцы start_at, end_at, arrived_at к формату даты, используя pd.to_datetime(). Отфильтруйте данные и оставьте наблюдения со статусом заказа "asap" и "reserved" (start_type) .

# %%
taxi = pd.read_csv('C:/Users/Eternity/taxi_peru.csv', sep=';')

# %%
taxi.head()
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#         icon start_type             start_at     start_lat     start_lon  \
# ...

# %%
taxi.dtypes
# Out:
# journey_id           object
# user_id              object
# driver_id            object
# taxi_id              object
# icon                 object
# start_type           object
# start_at             object
# start_lat            object
# start_lon            object
# end_at               object
# end_lat              object
# end_lon              object
# end_state            object
# driver_start_lat     object
# driver_start_lon     object
# arrived_at           object
# source               object
# driver_score        float64
# rider_score         float64
# dtype: object

# %%
taxi[['start_at', 'end_at', 'arrived_at']] = taxi[['start_at', 'end_at', 'arrived_at']].apply(pd.to_datetime)

# %%
taxi.dtypes
# Out:
# journey_id                  object
# user_id                     object
# driver_id                   object
# taxi_id                     object
# icon                        object
# start_type                  object
# start_at            datetime64[ns]
# start_lat                   object
# start_lon                   object
# end_at              datetime64[ns]
# end_lat                     object
# end_lon                     object
# end_state                   object
# driver_start_lat            object
# driver_start_lon            object
# arrived_at          datetime64[ns]
# source                      object
# driver_score               float64
# rider_score                float64
# dtype: object

# %%
taxi = taxi.query('start_type == "asap" or start_type == "reserved"')

# %% [markdown]
# ### 1.9 ⭐️Задание со звёздочкой!⭐️
# Создайте колонку wait_time, в которой будет храниться разница между временем подачи машины (arrived_at) и временем заказа (start_at) в минутах. Чтобы сконвертировать полученный результат в минуты, можно использовать метод  .astype('timedelta64[m]')

# %%
taxi['wait_time'] = (taxi['arrived_at'] - taxi['start_at']).astype('timedelta64[m]')
taxi.wait_time
# Out:
# 0        18.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4        -5.0
#          ...
# 23106     0.0
# 23107    13.0
# 23108     9.0
# 23109    -7.0
# 23110     NaN
# Name: wait_time, Length: 23091, dtype: float64

# %% [markdown]
# ### 1.10 ⭐️Задание со звёздочкой!⭐️
# Посмотрим, какие водители опаздывали на заказы к определенному времени (start_type == 'reserved'). Опозданием считается время ожидания wait_time > 0.0.
# Сгруппируйте отфильтрованные данные по driver_id и в качестве ответа укажите id водителя, который опоздал на заказ интересующего нас типа наибольшее число раз

# %%
taxi.query('start_type == "reserved" and wait_time > 0') \
    .groupby('driver_id') \
    .agg({'user_id': 'count'}) \
    .rename(columns={'user_id': 'count'}).idxmax()
# Out:
# count    406921adcca37705ef527b4246c0cfea
# dtype: object

# %% [markdown]
# ### 1.11 ⭐️Задание со звёздочкой!⭐️
# Добавьте столбец month, где будет храниться месяц, в котором был сделан заказ (start_at), как номер, и столбец weekday – название дня недели.

# %%
taxi['month'] = pd.DatetimeIndex(taxi['start_at']).month
taxi['month']
# Out:
# 0        11
# 1         6
# 2         5
# 3         6
# 4         9
#          ..
# 23106     7
# 23107    10
# 23108     9
# 23109     4
# 23110     3
# Name: month, Length: 23091, dtype: int64

# %%
taxi['weekday'] = taxi.start_at.dt.strftime('%A')
taxi.weekday
# Out:
# 0         Tuesday
# 1         Tuesday
# 2          Monday
# 3         Tuesday
# 4        Saturday
#            ...
# 23106    Saturday
# 23107    Saturday
# 23108     Tuesday
# 23109    Thursday
# 23110     Tuesday
# Name: weekday, Length: 23091, dtype: object

# %% [markdown]
# ### 1.12⭐️Задание со звёздочкой!⭐️
# Постройте график числа заказов по месяцам (month). Подумайте, с чем может быть связана полученная картина.
# Вопрос: в каком летнем месяце было сделано наименьшее число заказов? В качестве ответа введите номер месяца (6, 7 или 8).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = taxi.groupby('month', as_index=False).agg({'journey_id': 'count'}).rename(columns={'journey_id': 'count'})
x
# Out:
#     month  count
# 0       1    573
# 1       2    766
# 2       3    983
# 3       4   1445
# 4       5   1584
# 5       6   1936
# 6       7   1512
# 7       8   2120
# 8       9   2598
# 9      10   3240
# 10     11   3021
# 11     12   3313

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x="month", y="count", data = x)
sns.despine()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='month', data=taxi)
sns.despine()

# %% [markdown]
# ### 1.13 ⭐️Задание со звёздочкой!⭐️
# А теперь – график по дням недели (weekday). Задать порядок столбиков на графике можно с помощью аргумента order, которому нужно передать список названий в нужном порядке. Например:
# sns.countplot(data['column'], order=['One', 'Two', 'Three'])
# Вопрос: в какой день недели суммарно поступило меньше всего заказов?

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='weekday', data=taxi, order=['Sunday', 'Monday', 'Thursday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'])
sns.despine()

# %% [markdown]
# ### 1.14 ⭐️Задание со звёздочкой!⭐️
# Также мы можем посмотреть на несколько простых метрик, показывающих число уникальных пользователей за определённый период:
# * DAU (daily active users) – число уникальных пользователей за день
# * WAU (weekly active users) – число уникальных пользователей за неделю
# * MAU (monthly active users) – число уникальных пользователей за месяц
# Активные пользователи – те, кто воспользовался приложением и сделал хотя бы один заказ за выбранный промежуток времени. Постройте график MAU и выберите верные утверждения.
# Могут пригодиться:
# * groupby – группировка
# * nunique – число уникальных значений
# * plot.line – линейная диаграмма

# %%
taxi.head()
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#         icon start_type            start_at     start_lat     start_lon  \
# ...

# %%
taxi['year'] = pd.DatetimeIndex(taxi['start_at']).year

# %%
taxi.groupby(['year', 'month', 'weekday'], as_index=False).agg({'user_id': 'nunique'})
# Out:
#     year  month    weekday  user_id
# 0   2010      1     Friday       36
# 1   2010      1     Monday       32
# 2   2010      1   Saturday       29
# 3   2010      1     Sunday       37
# 4   2010      1   Thursday       30
# ..   ...    ...        ...      ...
# 79  2010     12   Saturday      172
# 80  2010     12     Sunday      181
# 81  2010     12   Thursday      166
# 82  2010     12    Tuesday      245
# 83  2010     12  Wednesday      191
#
# [84 rows x 4 columns]
